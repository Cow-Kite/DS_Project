# %% [markdown]
# 필요한 Library

# %%
from torch_geometric.datasets import Amazon
from torch_geometric.loader import NeighborLoader
from torch_geometric.utils import to_networkx
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import torch

# %% [markdown]
# Amazon Dataset

# %%
dataset = Amazon(root='./Amazon_data', name='computers')
data = dataset[0]

# %%
# Split the dataset into training, validation, and test sets
num_nodes = data.x.shape[0]
num_train = int(0.8 * num_nodes)
num_val = int(0.1 * num_nodes)
num_test = num_nodes - num_train - num_val

# Create masks for training, validation, and test nodes
data.train_mask = torch.zeros(num_nodes, dtype=torch.bool)
data.val_mask = torch.zeros(num_nodes, dtype=torch.bool)
data.test_mask = torch.zeros(num_nodes, dtype=torch.bool)

# Assign nodes to masks
data.train_mask[:num_train] = 1
data.val_mask[num_train:num_train + num_val] = 1
data.test_mask[num_train + num_val:] = 1

# %% [markdown]
# Graph 구조와 특징

# %%
# Print information about the dataset
print(f'Dataset: {dataset}')
print('-------------------')
print(f'Number of graphs: {len(dataset)}')
print(f'Number of nodes: {data.x.shape[0]}')
print(f'Number of features: {dataset.num_features}')
print(f'Number of classes: {dataset.num_classes}')

# Print information about the graph
print(f'\nGraph:')
print('------')
print(f'Training nodes: {num_train}')
print(f'Evaluation nodes: {num_val}')
print(f'Test nodes: {num_test}')
print(f'Edges are directed: {data.is_directed()}')
print(f'Graph has isolated nodes: {data.has_isolated_nodes()}')
print(f'Graph has loops: {data.has_self_loops()}')
# Out:
# Dataset: AmazonComputers()
# -------------------
# Number of graphs: 1
# Number of nodes: 13752
# Number of features: 767
# Number of classes: 10
#
# Graph:
# ------
# Training nodes: 11001
# Evaluation nodes: 1375
# Test nodes: 1376
# Edges are directed: False
# Graph has isolated nodes: True
# Graph has loops: False

# %% [markdown]
# Minibatch 생성
#
#
# Minibatch란 대용량의 Graph를 나누어 학습하기 위해 나온 것으로
# 학습할 노드들을 랜덤하게 선택하여 하나의 Minibatch를 생성
#
# 본 데이터 셋은 데이터의 양이 적어 Full-batch로 진행

# %%
# Create batches with neighbor sampling
train_loader = NeighborLoader(
    data,
    num_neighbors=[5,5],
    batch_size=1024,
    input_nodes=data.train_mask,
)

# %% [markdown]
# 생성된 Minibatch의 설명

# %%
# Print each subgraph
for i, subgraph in enumerate(train_loader):
    print(f'Subgraph {i}: {subgraph}')
# Out:
# Subgraph 0: Data(x=[8417, 767], edge_index=[2, 19740], y=[8417], train_mask=[8417], val_mask=[8417], test_mask=[8417], n_id=[8417], e_id=[19740], input_id=[1024], batch_size=1024)
# Subgraph 1: Data(x=[8443, 767], edge_index=[2, 19827], y=[8443], train_mask=[8443], val_mask=[8443], test_mask=[8443], n_id=[8443], e_id=[19827], input_id=[1024], batch_size=1024)
# Subgraph 2: Data(x=[8491, 767], edge_index=[2, 20010], y=[8491], train_mask=[8491], val_mask=[8491], test_mask=[8491], n_id=[8491], e_id=[20010], input_id=[1024], batch_size=1024)
# Subgraph 3: Data(x=[8377, 767], edge_index=[2, 19724], y=[8377], train_mask=[8377], val_mask=[8377], test_mask=[8377], n_id=[8377], e_id=[19724], input_id=[1024], batch_size=1024)
# Subgraph 4: Data(x=[8460, 767], edge_index=[2, 19962], y=[8460], train_mask=[8460], val_mask=[8460], test_mask=[8460], n_id=[8460], e_id=[19962], input_id=[1024], batch_size=1024)
# Subgraph 5: Data(x=[8399, 767], edge_index=[2, 19880], y=[8399], train_mask=[8399], val_mask=[8399], test_mask=[8399], n_id=[8399], e_id=[19880], input_id=[1024], batch_size=1024)
# Subgraph 6: Data(x=[8460, 767], edge_index=[2, 19830], y=[8460], train_mask=[8460], val_mask=[8460], test_mask=[8460], n_id=[8460], e_id=[19830], input_id=[1024], batch_size=1024)
# Subgraph 7: Data(x=[8414, 767], edge_index=[2, 19832], y=[8414], train_mask=[8414], val_mask=[8414], test_mask=[8414], n_id=[8414], e_id=[19832], input_id=[1024], batch_size=1024)
# Subgraph 8: Data(x=[8454, 767], edge_index=[2, 19763], y=[8454], train_mask=[8454], val_mask=[8454], test_mask=[8454], n_id=[8454], e_id=[19763], input_id=[1024], batch_size=1024)
# Subgraph 9: Data(x=[8427, 767], edge_index=[2, 19905], y=[8427], train_mask=[8427], val_mask=[8427], test_mask=[8427], n_id=[8427], e_id=[19905], input_id=[1024], batch_size=1024)
# Subgraph 10: Data(x=[7479, 767], edge_index=[2, 15719], y=[7479], train_mask=[7479], val_mask=[7479], test_mask=[7479], n_id=[7479], e_id=[15719], input_id=[761], batch_size=761)

# %% [markdown]
# Minibatch 시각화

# %%
# Plot each subgraph
fig = plt.figure(figsize=(8,8))
for idx, (subdata, pos) in enumerate(zip(train_loader, [221, 222, 223, 224])):
    G = to_networkx(subdata, to_undirected=True)
    ax = fig.add_subplot(pos)
    ax.set_title(f'Subgraph {idx}', fontsize=10)
    plt.axis('off')
    nx.draw_networkx(G,
                    pos=nx.spring_layout(G, seed=0),
                    with_labels=False,
                    node_color=subdata.y,
                    node_size = 100
                    )
plt.show()

# %%
import torch
torch.manual_seed(-1)
import torch.nn.functional as F
from torch_geometric.nn import SAGEConv

# %% [markdown]
# GraphSAGE 모델 구현

# %%
class GraphSAGE(torch.nn.Module):
    def __init__(self, dim_in, dim_h, dim_out):
        super().__init__()
        self.sage1 = SAGEConv(dim_in, dim_h) # default = mean aggregator
        self.sage2 = SAGEConv(dim_h, dim_out)

    def forward(self, x, edge_index):
        h = self.sage1(x, edge_index)
        h = torch.relu(h)
        h = F.dropout(h, p=0.5, training=self.training)
        h = self.sage2(h, edge_index)
        h = F.log_softmax(h, dim=1)
        return h

    def fit(self, data, epochs):
        criterion = torch.nn.CrossEntropyLoss()
        optimizer = torch.optim.Adam(self.parameters(), lr=0.01)

        self.train()
        for epoch in range(epochs+1):
            total_loss = 0
            acc = 0
            val_loss = 0
            val_acc = 0
            # Train on batches
            for batch in train_loader:
                optimizer.zero_grad()
                out = self(batch.x, batch.edge_index)
                loss = criterion(out[batch.train_mask], batch.y[batch.train_mask])
                total_loss += loss.item()
                acc += accuracy(out[batch.train_mask].argmax(dim=1), batch.y[batch.train_mask])
                loss.backward()
                optimizer.step()

                # Validation
                val_loss += criterion(out[batch.val_mask], batch.y[batch.val_mask])
                val_acc += accuracy(out[batch.val_mask].argmax(dim=1), batch.y[batch.val_mask])
                print(f'Batch : {batch}')
            # Print metrics every 10 epochs
            #if epoch % 20 == 0:
            print(f'Epoch {epoch:>3} | Train Loss: {loss/len(train_loader):.3f} | Train Acc: {acc/len(train_loader)*100:>6.2f}% | Val Loss: {val_loss/len(train_loader):.2f} | Val Acc: {val_acc/len(train_loader)*100:.2f}%')


    @torch.no_grad()
    def test(self, data):
        self.eval()
        out = self(data.x, data.edge_index)
        acc = accuracy(out.argmax(dim=1)[data.test_mask], data.y[data.test_mask])
        return acc

def accuracy(pred_y, y):
    return ((pred_y == y).sum() / len(y)).item()

# %% [markdown]
# 200번의 학습 (Epoch)을 통해
#
# 정확도: 77.9% 를 얻음

# %%
# Create GraphSAGE
graphsage = GraphSAGE(dataset.num_features, 64, dataset.num_classes)
print(graphsage)

# Train
graphsage.fit(data, 200)

# Test
acc = graphsage.test(data)
print(f'GraphSAGE test accuracy: {acc*100:.2f}%')
# Out:
# GraphSAGE(
#   (sage1): SAGEConv(767, 64, aggr=mean)
#   (sage2): SAGEConv(64, 10, aggr=mean)
# )
# Batch : Data(x=[8325, 767], edge_index=[2, 19800], y=[8325], train_mask=[8325], val_mask=[8325], test_mask=[8325], n_id=[8325], e_id=[19800], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8413, 767], edge_index=[2, 19762], y=[8413], train_mask=[8413], val_mask=[8413], test_mask=[8413], n_id=[8413], e_id=[19762], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8469, 767], edge_index=[2, 19972], y=[8469], train_mask=[8469], val_mask=[8469], test_mask=[8469], n_id=[8469], e_id=[19972], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8461, 767], edge_index=[2, 19667], y=[8461], train_mask=[8461], val_mask=[8461], test_mask=[8461], n_id=[8461], e_id=[19667], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8443, 767], edge_index=[2, 19936], y=[8443], train_mask=[8443], val_mask=[8443], test_mask=[8443], n_id=[8443], e_id=[19936], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8413, 767], edge_index=[2, 19830], y=[8413], train_mask=[8413], val_mask=[8413], test_mask=[8413], n_id=[8413], e_id=[19830], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8436, 767], edge_index=[2, 19863], y=[8436], train_mask=[8436], val_mask=[8436], test_mask=[8436], n_id=[8436], e_id=[19863], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8373, 767], edge_index=[2, 20011], y=[8373], train_mask=[8373], val_mask=[8373], test_mask=[8373], n_id=[8373], e_id=[20011], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8396, 767], edge_index=[2, 19558], y=[8396], train_mask=[8396], val_mask=[8396], test_mask=[8396], n_id=[8396], e_id=[19558], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8431, 767], edge_index=[2, 19994], y=[8431], train_mask=[8431], val_mask=[8431], test_mask=[8431], n_id=[8431], e_id=[19994], input_id=[1024], batch_size=1024)
# Batch : Data(x=[7440, 767], edge_index=[2, 15628], y=[7440], train_mask=[7440], val_mask=[7440], test_mask=[7440], n_id=[7440], e_id=[15628], input_id=[761], batch_size=761)
# Epoch   0 | Train Loss: 0.189 | Train Acc:  23.31% | Val Loss: 2.93 | Val Acc: 22.95%
# Batch : Data(x=[8428, 767], edge_index=[2, 19701], y=[8428], train_mask=[8428], val_mask=[8428], test_mask=[8428], n_id=[8428], e_id=[19701], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8420, 767], edge_index=[2, 19899], y=[8420], train_mask=[8420], val_mask=[8420], test_mask=[8420], n_id=[8420], e_id=[19899], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8463, 767], edge_index=[2, 19914], y=[8463], train_mask=[8463], val_mask=[8463], test_mask=[8463], n_id=[8463], e_id=[19914], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8431, 767], edge_index=[2, 19840], y=[8431], train_mask=[8431], val_mask=[8431], test_mask=[8431], n_id=[8431], e_id=[19840], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8508, 767], edge_index=[2, 20047], y=[8508], train_mask=[8508], val_mask=[8508], test_mask=[8508], n_id=[8508], e_id=[20047], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8420, 767], edge_index=[2, 19700], y=[8420], train_mask=[8420], val_mask=[8420], test_mask=[8420], n_id=[8420], e_id=[19700], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8501, 767], edge_index=[2, 19901], y=[8501], train_mask=[8501], val_mask=[8501], test_mask=[8501], n_id=[8501], e_id=[19901], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8432, 767], edge_index=[2, 20039], y=[8432], train_mask=[8432], val_mask=[8432], test_mask=[8432], n_id=[8432], e_id=[20039], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8412, 767], edge_index=[2, 19594], y=[8412], train_mask=[8412], val_mask=[8412], test_mask=[8412], n_id=[8412], e_id=[19594], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8381, 767], edge_index=[2, 19794], y=[8381], train_mask=[8381], val_mask=[8381], test_mask=[8381], n_id=[8381], e_id=[19794], input_id=[1024], batch_size=1024)
# Batch : Data(x=[7528, 767], edge_index=[2, 15887], y=[7528], train_mask=[7528], val_mask=[7528], test_mask=[7528], n_id=[7528], e_id=[15887], input_id=[761], batch_size=761)
# Epoch   1 | Train Loss: 0.161 | Train Acc:  34.32% | Val Loss: 1.93 | Val Acc: 33.10%
# Batch : Data(x=[8511, 767], edge_index=[2, 19740], y=[8511], train_mask=[8511], val_mask=[8511], test_mask=[8511], n_id=[8511], e_id=[19740], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8419, 767], edge_index=[2, 19809], y=[8419], train_mask=[8419], val_mask=[8419], test_mask=[8419], n_id=[8419], e_id=[19809], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8396, 767], edge_index=[2, 19700], y=[8396], train_mask=[8396], val_mask=[8396], test_mask=[8396], n_id=[8396], e_id=[19700], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8357, 767], edge_index=[2, 19703], y=[8357], train_mask=[8357], val_mask=[8357], test_mask=[8357], n_id=[8357], e_id=[19703], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8505, 767], edge_index=[2, 20073], y=[8505], train_mask=[8505], val_mask=[8505], test_mask=[8505], n_id=[8505], e_id=[20073], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8539, 767], edge_index=[2, 19920], y=[8539], train_mask=[8539], val_mask=[8539], test_mask=[8539], n_id=[8539], e_id=[19920], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8375, 767], edge_index=[2, 19744], y=[8375], train_mask=[8375], val_mask=[8375], test_mask=[8375], n_id=[8375], e_id=[19744], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8448, 767], edge_index=[2, 19969], y=[8448], train_mask=[8448], val_mask=[8448], test_mask=[8448], n_id=[8448], e_id=[19969], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8343, 767], edge_index=[2, 19616], y=[8343], train_mask=[8343], val_mask=[8343], test_mask=[8343], n_id=[8343], e_id=[19616], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8411, 767], edge_index=[2, 19741], y=[8411], train_mask=[8411], val_mask=[8411], test_mask=[8411], n_id=[8411], e_id=[19741], input_id=[1024], batch_size=1024)
# Batch : Data(x=[7528, 767], edge_index=[2, 15894], y=[7528], train_mask=[7528], val_mask=[7528], test_mask=[7528], n_id=[7528], e_id=[15894], input_id=[761], batch_size=761)
# Epoch   2 | Train Loss: 0.138 | Train Acc:  42.87% | Val Loss: 1.68 | Val Acc: 41.71%
# Batch : Data(x=[8514, 767], edge_index=[2, 19955], y=[8514], train_mask=[8514], val_mask=[8514], test_mask=[8514], n_id=[8514], e_id=[19955], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8433, 767], edge_index=[2, 19947], y=[8433], train_mask=[8433], val_mask=[8433], test_mask=[8433], n_id=[8433], e_id=[19947], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8491, 767], edge_index=[2, 19946], y=[8491], train_mask=[8491], val_mask=[8491], test_mask=[8491], n_id=[8491], e_id=[19946], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8452, 767], edge_index=[2, 19927], y=[8452], train_mask=[8452], val_mask=[8452], test_mask=[8452], n_id=[8452], e_id=[19927], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8511, 767], edge_index=[2, 20086], y=[8511], train_mask=[8511], val_mask=[8511], test_mask=[8511], n_id=[8511], e_id=[20086], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8458, 767], edge_index=[2, 19914], y=[8458], train_mask=[8458], val_mask=[8458], test_mask=[8458], n_id=[8458], e_id=[19914], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8407, 767], edge_index=[2, 19711], y=[8407], train_mask=[8407], val_mask=[8407], test_mask=[8407], n_id=[8407], e_id=[19711], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8352, 767], edge_index=[2, 19734], y=[8352], train_mask=[8352], val_mask=[8352], test_mask=[8352], n_id=[8352], e_id=[19734], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8415, 767], edge_index=[2, 19527], y=[8415], train_mask=[8415], val_mask=[8415], test_mask=[8415], n_id=[8415], e_id=[19527], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8417, 767], edge_index=[2, 19701], y=[8417], train_mask=[8417], val_mask=[8417], test_mask=[8417], n_id=[8417], e_id=[19701], input_id=[1024], batch_size=1024)
# Batch : Data(x=[7583, 767], edge_index=[2, 15863], y=[7583], train_mask=[7583], val_mask=[7583], test_mask=[7583], n_id=[7583], e_id=[15863], input_id=[761], batch_size=761)
# Epoch   3 | Train Loss: 0.123 | Train Acc:  50.63% | Val Loss: 1.46 | Val Acc: 49.19%
# Batch : Data(x=[8374, 767], edge_index=[2, 19901], y=[8374], train_mask=[8374], val_mask=[8374], test_mask=[8374], n_id=[8374], e_id=[19901], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8390, 767], edge_index=[2, 19818], y=[8390], train_mask=[8390], val_mask=[8390], test_mask=[8390], n_id=[8390], e_id=[19818], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8474, 767], edge_index=[2, 19792], y=[8474], train_mask=[8474], val_mask=[8474], test_mask=[8474], n_id=[8474], e_id=[19792], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8386, 767], edge_index=[2, 19680], y=[8386], train_mask=[8386], val_mask=[8386], test_mask=[8386], n_id=[8386], e_id=[19680], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8537, 767], edge_index=[2, 19884], y=[8537], train_mask=[8537], val_mask=[8537], test_mask=[8537], n_id=[8537], e_id=[19884], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8488, 767], edge_index=[2, 19828], y=[8488], train_mask=[8488], val_mask=[8488], test_mask=[8488], n_id=[8488], e_id=[19828], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8462, 767], edge_index=[2, 19876], y=[8462], train_mask=[8462], val_mask=[8462], test_mask=[8462], n_id=[8462], e_id=[19876], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8395, 767], edge_index=[2, 19940], y=[8395], train_mask=[8395], val_mask=[8395], test_mask=[8395], n_id=[8395], e_id=[19940], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8460, 767], edge_index=[2, 19739], y=[8460], train_mask=[8460], val_mask=[8460], test_mask=[8460], n_id=[8460], e_id=[19739], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8416, 767], edge_index=[2, 19600], y=[8416], train_mask=[8416], val_mask=[8416], test_mask=[8416], n_id=[8416], e_id=[19600], input_id=[1024], batch_size=1024)
# Batch : Data(x=[7494, 767], edge_index=[2, 15624], y=[7494], train_mask=[7494], val_mask=[7494], test_mask=[7494], n_id=[7494], e_id=[15624], input_id=[761], batch_size=761)
# Epoch   4 | Train Loss: 0.108 | Train Acc:  54.45% | Val Loss: 1.32 | Val Acc: 51.94%
# Batch : Data(x=[8321, 767], edge_index=[2, 19357], y=[8321], train_mask=[8321], val_mask=[8321], test_mask=[8321], n_id=[8321], e_id=[19357], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8436, 767], edge_index=[2, 19836], y=[8436], train_mask=[8436], val_mask=[8436], test_mask=[8436], n_id=[8436], e_id=[19836], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8476, 767], edge_index=[2, 20042], y=[8476], train_mask=[8476], val_mask=[8476], test_mask=[8476], n_id=[8476], e_id=[20042], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8381, 767], edge_index=[2, 19831], y=[8381], train_mask=[8381], val_mask=[8381], test_mask=[8381], n_id=[8381], e_id=[19831], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8468, 767], edge_index=[2, 19740], y=[8468], train_mask=[8468], val_mask=[8468], test_mask=[8468], n_id=[8468], e_id=[19740], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8388, 767], edge_index=[2, 19831], y=[8388], train_mask=[8388], val_mask=[8388], test_mask=[8388], n_id=[8388], e_id=[19831], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8482, 767], edge_index=[2, 19832], y=[8482], train_mask=[8482], val_mask=[8482], test_mask=[8482], n_id=[8482], e_id=[19832], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8391, 767], edge_index=[2, 19864], y=[8391], train_mask=[8391], val_mask=[8391], test_mask=[8391], n_id=[8391], e_id=[19864], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8450, 767], edge_index=[2, 19807], y=[8450], train_mask=[8450], val_mask=[8450], test_mask=[8450], n_id=[8450], e_id=[19807], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8387, 767], edge_index=[2, 19818], y=[8387], train_mask=[8387], val_mask=[8387], test_mask=[8387], n_id=[8387], e_id=[19818], input_id=[1024], batch_size=1024)
# Batch : Data(x=[7450, 767], edge_index=[2, 15762], y=[7450], train_mask=[7450], val_mask=[7450], test_mask=[7450], n_id=[7450], e_id=[15762], input_id=[761], batch_size=761)
# Epoch   5 | Train Loss: 0.102 | Train Acc:  58.96% | Val Loss: 1.20 | Val Acc: 56.03%
# Batch : Data(x=[8365, 767], edge_index=[2, 19808], y=[8365], train_mask=[8365], val_mask=[8365], test_mask=[8365], n_id=[8365], e_id=[19808], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8348, 767], edge_index=[2, 19771], y=[8348], train_mask=[8348], val_mask=[8348], test_mask=[8348], n_id=[8348], e_id=[19771], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8532, 767], edge_index=[2, 19855], y=[8532], train_mask=[8532], val_mask=[8532], test_mask=[8532], n_id=[8532], e_id=[19855], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8346, 767], edge_index=[2, 19628], y=[8346], train_mask=[8346], val_mask=[8346], test_mask=[8346], n_id=[8346], e_id=[19628], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8486, 767], edge_index=[2, 19999], y=[8486], train_mask=[8486], val_mask=[8486], test_mask=[8486], n_id=[8486], e_id=[19999], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8452, 767], edge_index=[2, 19811], y=[8452], train_mask=[8452], val_mask=[8452], test_mask=[8452], n_id=[8452], e_id=[19811], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8423, 767], edge_index=[2, 19841], y=[8423], train_mask=[8423], val_mask=[8423], test_mask=[8423], n_id=[8423], e_id=[19841], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8356, 767], edge_index=[2, 19697], y=[8356], train_mask=[8356], val_mask=[8356], test_mask=[8356], n_id=[8356], e_id=[19697], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8459, 767], edge_index=[2, 19544], y=[8459], train_mask=[8459], val_mask=[8459], test_mask=[8459], n_id=[8459], e_id=[19544], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8361, 767], edge_index=[2, 19803], y=[8361], train_mask=[8361], val_mask=[8361], test_mask=[8361], n_id=[8361], e_id=[19803], input_id=[1024], batch_size=1024)
# Batch : Data(x=[7499, 767], edge_index=[2, 15600], y=[7499], train_mask=[7499], val_mask=[7499], test_mask=[7499], n_id=[7499], e_id=[15600], input_id=[761], batch_size=761)
# Epoch   6 | Train Loss: 0.094 | Train Acc:  62.34% | Val Loss: 1.12 | Val Acc: 59.58%
# Batch : Data(x=[8421, 767], edge_index=[2, 19728], y=[8421], train_mask=[8421], val_mask=[8421], test_mask=[8421], n_id=[8421], e_id=[19728], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8458, 767], edge_index=[2, 19724], y=[8458], train_mask=[8458], val_mask=[8458], test_mask=[8458], n_id=[8458], e_id=[19724], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8442, 767], edge_index=[2, 19959], y=[8442], train_mask=[8442], val_mask=[8442], test_mask=[8442], n_id=[8442], e_id=[19959], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8436, 767], edge_index=[2, 19817], y=[8436], train_mask=[8436], val_mask=[8436], test_mask=[8436], n_id=[8436], e_id=[19817], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8395, 767], edge_index=[2, 19747], y=[8395], train_mask=[8395], val_mask=[8395], test_mask=[8395], n_id=[8395], e_id=[19747], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8413, 767], edge_index=[2, 19863], y=[8413], train_mask=[8413], val_mask=[8413], test_mask=[8413], n_id=[8413], e_id=[19863], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8465, 767], edge_index=[2, 19870], y=[8465], train_mask=[8465], val_mask=[8465], test_mask=[8465], n_id=[8465], e_id=[19870], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8472, 767], edge_index=[2, 20029], y=[8472], train_mask=[8472], val_mask=[8472], test_mask=[8472], n_id=[8472], e_id=[20029], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8410, 767], edge_index=[2, 19601], y=[8410], train_mask=[8410], val_mask=[8410], test_mask=[8410], n_id=[8410], e_id=[19601], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8400, 767], edge_index=[2, 19662], y=[8400], train_mask=[8400], val_mask=[8400], test_mask=[8400], n_id=[8400], e_id=[19662], input_id=[1024], batch_size=1024)
# Batch : Data(x=[7531, 767], edge_index=[2, 15765], y=[7531], train_mask=[7531], val_mask=[7531], test_mask=[7531], n_id=[7531], e_id=[15765], input_id=[761], batch_size=761)
# Epoch   7 | Train Loss: 0.090 | Train Acc:  64.66% | Val Loss: 1.04 | Val Acc: 62.44%
# Batch : Data(x=[8441, 767], edge_index=[2, 19987], y=[8441], train_mask=[8441], val_mask=[8441], test_mask=[8441], n_id=[8441], e_id=[19987], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8407, 767], edge_index=[2, 19860], y=[8407], train_mask=[8407], val_mask=[8407], test_mask=[8407], n_id=[8407], e_id=[19860], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8433, 767], edge_index=[2, 19944], y=[8433], train_mask=[8433], val_mask=[8433], test_mask=[8433], n_id=[8433], e_id=[19944], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8471, 767], edge_index=[2, 19930], y=[8471], train_mask=[8471], val_mask=[8471], test_mask=[8471], n_id=[8471], e_id=[19930], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8459, 767], edge_index=[2, 19792], y=[8459], train_mask=[8459], val_mask=[8459], test_mask=[8459], n_id=[8459], e_id=[19792], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8359, 767], edge_index=[2, 19642], y=[8359], train_mask=[8359], val_mask=[8359], test_mask=[8359], n_id=[8359], e_id=[19642], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8427, 767], edge_index=[2, 19836], y=[8427], train_mask=[8427], val_mask=[8427], test_mask=[8427], n_id=[8427], e_id=[19836], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8439, 767], edge_index=[2, 19937], y=[8439], train_mask=[8439], val_mask=[8439], test_mask=[8439], n_id=[8439], e_id=[19937], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8488, 767], edge_index=[2, 19755], y=[8488], train_mask=[8488], val_mask=[8488], test_mask=[8488], n_id=[8488], e_id=[19755], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8447, 767], edge_index=[2, 19848], y=[8447], train_mask=[8447], val_mask=[8447], test_mask=[8447], n_id=[8447], e_id=[19848], input_id=[1024], batch_size=1024)
# Batch : Data(x=[7517, 767], edge_index=[2, 15813], y=[7517], train_mask=[7517], val_mask=[7517], test_mask=[7517], n_id=[7517], e_id=[15813], input_id=[761], batch_size=761)
# Epoch   8 | Train Loss: 0.087 | Train Acc:  66.04% | Val Loss: 1.00 | Val Acc: 64.19%
# Batch : Data(x=[8496, 767], edge_index=[2, 19828], y=[8496], train_mask=[8496], val_mask=[8496], test_mask=[8496], n_id=[8496], e_id=[19828], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8461, 767], edge_index=[2, 20011], y=[8461], train_mask=[8461], val_mask=[8461], test_mask=[8461], n_id=[8461], e_id=[20011], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8462, 767], edge_index=[2, 20019], y=[8462], train_mask=[8462], val_mask=[8462], test_mask=[8462], n_id=[8462], e_id=[20019], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8412, 767], edge_index=[2, 19795], y=[8412], train_mask=[8412], val_mask=[8412], test_mask=[8412], n_id=[8412], e_id=[19795], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8472, 767], edge_index=[2, 19893], y=[8472], train_mask=[8472], val_mask=[8472], test_mask=[8472], n_id=[8472], e_id=[19893], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8467, 767], edge_index=[2, 20030], y=[8467], train_mask=[8467], val_mask=[8467], test_mask=[8467], n_id=[8467], e_id=[20030], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8412, 767], edge_index=[2, 19838], y=[8412], train_mask=[8412], val_mask=[8412], test_mask=[8412], n_id=[8412], e_id=[19838], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8406, 767], edge_index=[2, 20001], y=[8406], train_mask=[8406], val_mask=[8406], test_mask=[8406], n_id=[8406], e_id=[20001], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8436, 767], edge_index=[2, 19791], y=[8436], train_mask=[8436], val_mask=[8436], test_mask=[8436], n_id=[8436], e_id=[19791], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8363, 767], edge_index=[2, 19744], y=[8363], train_mask=[8363], val_mask=[8363], test_mask=[8363], n_id=[8363], e_id=[19744], input_id=[1024], batch_size=1024)
# Batch : Data(x=[7528, 767], edge_index=[2, 15764], y=[7528], train_mask=[7528], val_mask=[7528], test_mask=[7528], n_id=[7528], e_id=[15764], input_id=[761], batch_size=761)
# Epoch   9 | Train Loss: 0.081 | Train Acc:  68.30% | Val Loss: 0.97 | Val Acc: 66.04%
# Batch : Data(x=[8409, 767], edge_index=[2, 19714], y=[8409], train_mask=[8409], val_mask=[8409], test_mask=[8409], n_id=[8409], e_id=[19714], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8405, 767], edge_index=[2, 19701], y=[8405], train_mask=[8405], val_mask=[8405], test_mask=[8405], n_id=[8405], e_id=[19701], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8498, 767], edge_index=[2, 19929], y=[8498], train_mask=[8498], val_mask=[8498], test_mask=[8498], n_id=[8498], e_id=[19929], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8370, 767], edge_index=[2, 19791], y=[8370], train_mask=[8370], val_mask=[8370], test_mask=[8370], n_id=[8370], e_id=[19791], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8516, 767], edge_index=[2, 19835], y=[8516], train_mask=[8516], val_mask=[8516], test_mask=[8516], n_id=[8516], e_id=[19835], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8432, 767], edge_index=[2, 19854], y=[8432], train_mask=[8432], val_mask=[8432], test_mask=[8432], n_id=[8432], e_id=[19854], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8437, 767], edge_index=[2, 19723], y=[8437], train_mask=[8437], val_mask=[8437], test_mask=[8437], n_id=[8437], e_id=[19723], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8455, 767], edge_index=[2, 20055], y=[8455], train_mask=[8455], val_mask=[8455], test_mask=[8455], n_id=[8455], e_id=[20055], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8367, 767], edge_index=[2, 19656], y=[8367], train_mask=[8367], val_mask=[8367], test_mask=[8367], n_id=[8367], e_id=[19656], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8388, 767], edge_index=[2, 19778], y=[8388], train_mask=[8388], val_mask=[8388], test_mask=[8388], n_id=[8388], e_id=[19778], input_id=[1024], batch_size=1024)
# Batch : Data(x=[7551, 767], edge_index=[2, 15823], y=[7551], train_mask=[7551], val_mask=[7551], test_mask=[7551], n_id=[7551], e_id=[15823], input_id=[761], batch_size=761)
# Epoch  10 | Train Loss: 0.076 | Train Acc:  70.07% | Val Loss: 0.93 | Val Acc: 66.83%
# Batch : Data(x=[8436, 767], edge_index=[2, 19771], y=[8436], train_mask=[8436], val_mask=[8436], test_mask=[8436], n_id=[8436], e_id=[19771], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8446, 767], edge_index=[2, 19897], y=[8446], train_mask=[8446], val_mask=[8446], test_mask=[8446], n_id=[8446], e_id=[19897], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8479, 767], edge_index=[2, 19853], y=[8479], train_mask=[8479], val_mask=[8479], test_mask=[8479], n_id=[8479], e_id=[19853], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8522, 767], edge_index=[2, 19943], y=[8522], train_mask=[8522], val_mask=[8522], test_mask=[8522], n_id=[8522], e_id=[19943], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8389, 767], edge_index=[2, 19965], y=[8389], train_mask=[8389], val_mask=[8389], test_mask=[8389], n_id=[8389], e_id=[19965], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8421, 767], edge_index=[2, 19803], y=[8421], train_mask=[8421], val_mask=[8421], test_mask=[8421], n_id=[8421], e_id=[19803], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8482, 767], edge_index=[2, 20008], y=[8482], train_mask=[8482], val_mask=[8482], test_mask=[8482], n_id=[8482], e_id=[20008], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8433, 767], edge_index=[2, 19818], y=[8433], train_mask=[8433], val_mask=[8433], test_mask=[8433], n_id=[8433], e_id=[19818], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8462, 767], edge_index=[2, 19575], y=[8462], train_mask=[8462], val_mask=[8462], test_mask=[8462], n_id=[8462], e_id=[19575], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8396, 767], edge_index=[2, 19748], y=[8396], train_mask=[8396], val_mask=[8396], test_mask=[8396], n_id=[8396], e_id=[19748], input_id=[1024], batch_size=1024)
# Batch : Data(x=[7587, 767], edge_index=[2, 15759], y=[7587], train_mask=[7587], val_mask=[7587], test_mask=[7587], n_id=[7587], e_id=[15759], input_id=[761], batch_size=761)
# Epoch  11 | Train Loss: 0.074 | Train Acc:  71.14% | Val Loss: 0.88 | Val Acc: 68.37%
# Batch : Data(x=[8444, 767], edge_index=[2, 19838], y=[8444], train_mask=[8444], val_mask=[8444], test_mask=[8444], n_id=[8444], e_id=[19838], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8330, 767], edge_index=[2, 19676], y=[8330], train_mask=[8330], val_mask=[8330], test_mask=[8330], n_id=[8330], e_id=[19676], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8416, 767], edge_index=[2, 19892], y=[8416], train_mask=[8416], val_mask=[8416], test_mask=[8416], n_id=[8416], e_id=[19892], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8399, 767], edge_index=[2, 19918], y=[8399], train_mask=[8399], val_mask=[8399], test_mask=[8399], n_id=[8399], e_id=[19918], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8556, 767], edge_index=[2, 20045], y=[8556], train_mask=[8556], val_mask=[8556], test_mask=[8556], n_id=[8556], e_id=[20045], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8401, 767], edge_index=[2, 19647], y=[8401], train_mask=[8401], val_mask=[8401], test_mask=[8401], n_id=[8401], e_id=[19647], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8391, 767], edge_index=[2, 19725], y=[8391], train_mask=[8391], val_mask=[8391], test_mask=[8391], n_id=[8391], e_id=[19725], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8377, 767], edge_index=[2, 19623], y=[8377], train_mask=[8377], val_mask=[8377], test_mask=[8377], n_id=[8377], e_id=[19623], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8429, 767], edge_index=[2, 19625], y=[8429], train_mask=[8429], val_mask=[8429], test_mask=[8429], n_id=[8429], e_id=[19625], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8413, 767], edge_index=[2, 19802], y=[8413], train_mask=[8413], val_mask=[8413], test_mask=[8413], n_id=[8413], e_id=[19802], input_id=[1024], batch_size=1024)
# Batch : Data(x=[7518, 767], edge_index=[2, 15733], y=[7518], train_mask=[7518], val_mask=[7518], test_mask=[7518], n_id=[7518], e_id=[15733], input_id=[761], batch_size=761)
# Epoch  12 | Train Loss: 0.073 | Train Acc:  71.77% | Val Loss: 0.86 | Val Acc: 69.01%
# Batch : Data(x=[8318, 767], edge_index=[2, 19501], y=[8318], train_mask=[8318], val_mask=[8318], test_mask=[8318], n_id=[8318], e_id=[19501], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8451, 767], edge_index=[2, 19896], y=[8451], train_mask=[8451], val_mask=[8451], test_mask=[8451], n_id=[8451], e_id=[19896], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8527, 767], edge_index=[2, 20044], y=[8527], train_mask=[8527], val_mask=[8527], test_mask=[8527], n_id=[8527], e_id=[20044], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8447, 767], edge_index=[2, 19876], y=[8447], train_mask=[8447], val_mask=[8447], test_mask=[8447], n_id=[8447], e_id=[19876], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8589, 767], edge_index=[2, 20106], y=[8589], train_mask=[8589], val_mask=[8589], test_mask=[8589], n_id=[8589], e_id=[20106], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8553, 767], edge_index=[2, 20207], y=[8553], train_mask=[8553], val_mask=[8553], test_mask=[8553], n_id=[8553], e_id=[20207], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8373, 767], edge_index=[2, 19722], y=[8373], train_mask=[8373], val_mask=[8373], test_mask=[8373], n_id=[8373], e_id=[19722], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8326, 767], edge_index=[2, 19784], y=[8326], train_mask=[8326], val_mask=[8326], test_mask=[8326], n_id=[8326], e_id=[19784], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8431, 767], edge_index=[2, 19735], y=[8431], train_mask=[8431], val_mask=[8431], test_mask=[8431], n_id=[8431], e_id=[19735], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8474, 767], edge_index=[2, 20091], y=[8474], train_mask=[8474], val_mask=[8474], test_mask=[8474], n_id=[8474], e_id=[20091], input_id=[1024], batch_size=1024)
# Batch : Data(x=[7504, 767], edge_index=[2, 15666], y=[7504], train_mask=[7504], val_mask=[7504], test_mask=[7504], n_id=[7504], e_id=[15666], input_id=[761], batch_size=761)
# Epoch  13 | Train Loss: 0.070 | Train Acc:  72.53% | Val Loss: 0.85 | Val Acc: 69.67%
# Batch : Data(x=[8504, 767], edge_index=[2, 19899], y=[8504], train_mask=[8504], val_mask=[8504], test_mask=[8504], n_id=[8504], e_id=[19899], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8387, 767], edge_index=[2, 19686], y=[8387], train_mask=[8387], val_mask=[8387], test_mask=[8387], n_id=[8387], e_id=[19686], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8375, 767], edge_index=[2, 19958], y=[8375], train_mask=[8375], val_mask=[8375], test_mask=[8375], n_id=[8375], e_id=[19958], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8404, 767], edge_index=[2, 19883], y=[8404], train_mask=[8404], val_mask=[8404], test_mask=[8404], n_id=[8404], e_id=[19883], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8458, 767], edge_index=[2, 19918], y=[8458], train_mask=[8458], val_mask=[8458], test_mask=[8458], n_id=[8458], e_id=[19918], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8413, 767], edge_index=[2, 19656], y=[8413], train_mask=[8413], val_mask=[8413], test_mask=[8413], n_id=[8413], e_id=[19656], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8412, 767], edge_index=[2, 19690], y=[8412], train_mask=[8412], val_mask=[8412], test_mask=[8412], n_id=[8412], e_id=[19690], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8418, 767], edge_index=[2, 20015], y=[8418], train_mask=[8418], val_mask=[8418], test_mask=[8418], n_id=[8418], e_id=[20015], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8392, 767], edge_index=[2, 19646], y=[8392], train_mask=[8392], val_mask=[8392], test_mask=[8392], n_id=[8392], e_id=[19646], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8456, 767], edge_index=[2, 20014], y=[8456], train_mask=[8456], val_mask=[8456], test_mask=[8456], n_id=[8456], e_id=[20014], input_id=[1024], batch_size=1024)
# Batch : Data(x=[7526, 767], edge_index=[2, 15649], y=[7526], train_mask=[7526], val_mask=[7526], test_mask=[7526], n_id=[7526], e_id=[15649], input_id=[761], batch_size=761)
# Epoch  14 | Train Loss: 0.070 | Train Acc:  73.01% | Val Loss: 0.83 | Val Acc: 69.78%
# Batch : Data(x=[8499, 767], edge_index=[2, 19950], y=[8499], train_mask=[8499], val_mask=[8499], test_mask=[8499], n_id=[8499], e_id=[19950], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8471, 767], edge_index=[2, 19961], y=[8471], train_mask=[8471], val_mask=[8471], test_mask=[8471], n_id=[8471], e_id=[19961], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8465, 767], edge_index=[2, 19966], y=[8465], train_mask=[8465], val_mask=[8465], test_mask=[8465], n_id=[8465], e_id=[19966], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8459, 767], edge_index=[2, 19788], y=[8459], train_mask=[8459], val_mask=[8459], test_mask=[8459], n_id=[8459], e_id=[19788], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8474, 767], edge_index=[2, 20037], y=[8474], train_mask=[8474], val_mask=[8474], test_mask=[8474], n_id=[8474], e_id=[20037], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8499, 767], edge_index=[2, 19938], y=[8499], train_mask=[8499], val_mask=[8499], test_mask=[8499], n_id=[8499], e_id=[19938], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8431, 767], edge_index=[2, 19743], y=[8431], train_mask=[8431], val_mask=[8431], test_mask=[8431], n_id=[8431], e_id=[19743], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8393, 767], edge_index=[2, 19611], y=[8393], train_mask=[8393], val_mask=[8393], test_mask=[8393], n_id=[8393], e_id=[19611], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8490, 767], edge_index=[2, 19826], y=[8490], train_mask=[8490], val_mask=[8490], test_mask=[8490], n_id=[8490], e_id=[19826], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8360, 767], edge_index=[2, 19944], y=[8360], train_mask=[8360], val_mask=[8360], test_mask=[8360], n_id=[8360], e_id=[19944], input_id=[1024], batch_size=1024)
# Batch : Data(x=[7551, 767], edge_index=[2, 15832], y=[7551], train_mask=[7551], val_mask=[7551], test_mask=[7551], n_id=[7551], e_id=[15832], input_id=[761], batch_size=761)
# Epoch  15 | Train Loss: 0.067 | Train Acc:  73.91% | Val Loss: 0.82 | Val Acc: 70.38%
# Batch : Data(x=[8406, 767], edge_index=[2, 19849], y=[8406], train_mask=[8406], val_mask=[8406], test_mask=[8406], n_id=[8406], e_id=[19849], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8475, 767], edge_index=[2, 19953], y=[8475], train_mask=[8475], val_mask=[8475], test_mask=[8475], n_id=[8475], e_id=[19953], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8474, 767], edge_index=[2, 19970], y=[8474], train_mask=[8474], val_mask=[8474], test_mask=[8474], n_id=[8474], e_id=[19970], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8425, 767], edge_index=[2, 19835], y=[8425], train_mask=[8425], val_mask=[8425], test_mask=[8425], n_id=[8425], e_id=[19835], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8482, 767], edge_index=[2, 19853], y=[8482], train_mask=[8482], val_mask=[8482], test_mask=[8482], n_id=[8482], e_id=[19853], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8413, 767], edge_index=[2, 19731], y=[8413], train_mask=[8413], val_mask=[8413], test_mask=[8413], n_id=[8413], e_id=[19731], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8540, 767], edge_index=[2, 19941], y=[8540], train_mask=[8540], val_mask=[8540], test_mask=[8540], n_id=[8540], e_id=[19941], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8408, 767], edge_index=[2, 19869], y=[8408], train_mask=[8408], val_mask=[8408], test_mask=[8408], n_id=[8408], e_id=[19869], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8396, 767], edge_index=[2, 19667], y=[8396], train_mask=[8396], val_mask=[8396], test_mask=[8396], n_id=[8396], e_id=[19667], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8384, 767], edge_index=[2, 19679], y=[8384], train_mask=[8384], val_mask=[8384], test_mask=[8384], n_id=[8384], e_id=[19679], input_id=[1024], batch_size=1024)
# Batch : Data(x=[7521, 767], edge_index=[2, 15838], y=[7521], train_mask=[7521], val_mask=[7521], test_mask=[7521], n_id=[7521], e_id=[15838], input_id=[761], batch_size=761)
# Epoch  16 | Train Loss: 0.067 | Train Acc:  74.01% | Val Loss: 0.82 | Val Acc: 70.88%
# Batch : Data(x=[8415, 767], edge_index=[2, 19817], y=[8415], train_mask=[8415], val_mask=[8415], test_mask=[8415], n_id=[8415], e_id=[19817], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8368, 767], edge_index=[2, 19702], y=[8368], train_mask=[8368], val_mask=[8368], test_mask=[8368], n_id=[8368], e_id=[19702], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8468, 767], edge_index=[2, 20133], y=[8468], train_mask=[8468], val_mask=[8468], test_mask=[8468], n_id=[8468], e_id=[20133], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8428, 767], edge_index=[2, 19813], y=[8428], train_mask=[8428], val_mask=[8428], test_mask=[8428], n_id=[8428], e_id=[19813], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8477, 767], edge_index=[2, 19912], y=[8477], train_mask=[8477], val_mask=[8477], test_mask=[8477], n_id=[8477], e_id=[19912], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8372, 767], edge_index=[2, 19638], y=[8372], train_mask=[8372], val_mask=[8372], test_mask=[8372], n_id=[8372], e_id=[19638], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8450, 767], edge_index=[2, 19986], y=[8450], train_mask=[8450], val_mask=[8450], test_mask=[8450], n_id=[8450], e_id=[19986], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8381, 767], edge_index=[2, 19871], y=[8381], train_mask=[8381], val_mask=[8381], test_mask=[8381], n_id=[8381], e_id=[19871], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8387, 767], edge_index=[2, 19476], y=[8387], train_mask=[8387], val_mask=[8387], test_mask=[8387], n_id=[8387], e_id=[19476], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8395, 767], edge_index=[2, 19920], y=[8395], train_mask=[8395], val_mask=[8395], test_mask=[8395], n_id=[8395], e_id=[19920], input_id=[1024], batch_size=1024)
# Batch : Data(x=[7467, 767], edge_index=[2, 15617], y=[7467], train_mask=[7467], val_mask=[7467], test_mask=[7467], n_id=[7467], e_id=[15617], input_id=[761], batch_size=761)
# Epoch  17 | Train Loss: 0.066 | Train Acc:  74.34% | Val Loss: 0.79 | Val Acc: 71.75%
# Batch : Data(x=[8364, 767], edge_index=[2, 19615], y=[8364], train_mask=[8364], val_mask=[8364], test_mask=[8364], n_id=[8364], e_id=[19615], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8447, 767], edge_index=[2, 19893], y=[8447], train_mask=[8447], val_mask=[8447], test_mask=[8447], n_id=[8447], e_id=[19893], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8451, 767], edge_index=[2, 20226], y=[8451], train_mask=[8451], val_mask=[8451], test_mask=[8451], n_id=[8451], e_id=[20226], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8355, 767], edge_index=[2, 19689], y=[8355], train_mask=[8355], val_mask=[8355], test_mask=[8355], n_id=[8355], e_id=[19689], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8403, 767], edge_index=[2, 19805], y=[8403], train_mask=[8403], val_mask=[8403], test_mask=[8403], n_id=[8403], e_id=[19805], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8460, 767], edge_index=[2, 19665], y=[8460], train_mask=[8460], val_mask=[8460], test_mask=[8460], n_id=[8460], e_id=[19665], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8457, 767], edge_index=[2, 19815], y=[8457], train_mask=[8457], val_mask=[8457], test_mask=[8457], n_id=[8457], e_id=[19815], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8478, 767], edge_index=[2, 20048], y=[8478], train_mask=[8478], val_mask=[8478], test_mask=[8478], n_id=[8478], e_id=[20048], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8425, 767], edge_index=[2, 19620], y=[8425], train_mask=[8425], val_mask=[8425], test_mask=[8425], n_id=[8425], e_id=[19620], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8374, 767], edge_index=[2, 19715], y=[8374], train_mask=[8374], val_mask=[8374], test_mask=[8374], n_id=[8374], e_id=[19715], input_id=[1024], batch_size=1024)
# Batch : Data(x=[7519, 767], edge_index=[2, 15689], y=[7519], train_mask=[7519], val_mask=[7519], test_mask=[7519], n_id=[7519], e_id=[15689], input_id=[761], batch_size=761)
# Epoch  18 | Train Loss: 0.065 | Train Acc:  74.37% | Val Loss: 0.82 | Val Acc: 69.99%
# Batch : Data(x=[8458, 767], edge_index=[2, 19693], y=[8458], train_mask=[8458], val_mask=[8458], test_mask=[8458], n_id=[8458], e_id=[19693], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8436, 767], edge_index=[2, 19814], y=[8436], train_mask=[8436], val_mask=[8436], test_mask=[8436], n_id=[8436], e_id=[19814], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8533, 767], edge_index=[2, 20074], y=[8533], train_mask=[8533], val_mask=[8533], test_mask=[8533], n_id=[8533], e_id=[20074], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8450, 767], edge_index=[2, 19907], y=[8450], train_mask=[8450], val_mask=[8450], test_mask=[8450], n_id=[8450], e_id=[19907], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8466, 767], edge_index=[2, 20031], y=[8466], train_mask=[8466], val_mask=[8466], test_mask=[8466], n_id=[8466], e_id=[20031], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8479, 767], edge_index=[2, 19892], y=[8479], train_mask=[8479], val_mask=[8479], test_mask=[8479], n_id=[8479], e_id=[19892], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8436, 767], edge_index=[2, 19854], y=[8436], train_mask=[8436], val_mask=[8436], test_mask=[8436], n_id=[8436], e_id=[19854], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8417, 767], edge_index=[2, 19825], y=[8417], train_mask=[8417], val_mask=[8417], test_mask=[8417], n_id=[8417], e_id=[19825], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8379, 767], edge_index=[2, 19497], y=[8379], train_mask=[8379], val_mask=[8379], test_mask=[8379], n_id=[8379], e_id=[19497], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8429, 767], edge_index=[2, 19762], y=[8429], train_mask=[8429], val_mask=[8429], test_mask=[8429], n_id=[8429], e_id=[19762], input_id=[1024], batch_size=1024)
# Batch : Data(x=[7554, 767], edge_index=[2, 15726], y=[7554], train_mask=[7554], val_mask=[7554], test_mask=[7554], n_id=[7554], e_id=[15726], input_id=[761], batch_size=761)
# Epoch  19 | Train Loss: 0.064 | Train Acc:  74.60% | Val Loss: 0.80 | Val Acc: 71.21%
# Batch : Data(x=[8388, 767], edge_index=[2, 19692], y=[8388], train_mask=[8388], val_mask=[8388], test_mask=[8388], n_id=[8388], e_id=[19692], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8368, 767], edge_index=[2, 19642], y=[8368], train_mask=[8368], val_mask=[8368], test_mask=[8368], n_id=[8368], e_id=[19642], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8457, 767], edge_index=[2, 19998], y=[8457], train_mask=[8457], val_mask=[8457], test_mask=[8457], n_id=[8457], e_id=[19998], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8434, 767], edge_index=[2, 19853], y=[8434], train_mask=[8434], val_mask=[8434], test_mask=[8434], n_id=[8434], e_id=[19853], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8424, 767], edge_index=[2, 19894], y=[8424], train_mask=[8424], val_mask=[8424], test_mask=[8424], n_id=[8424], e_id=[19894], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8358, 767], edge_index=[2, 19745], y=[8358], train_mask=[8358], val_mask=[8358], test_mask=[8358], n_id=[8358], e_id=[19745], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8471, 767], edge_index=[2, 19909], y=[8471], train_mask=[8471], val_mask=[8471], test_mask=[8471], n_id=[8471], e_id=[19909], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8391, 767], edge_index=[2, 19973], y=[8391], train_mask=[8391], val_mask=[8391], test_mask=[8391], n_id=[8391], e_id=[19973], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8376, 767], edge_index=[2, 19617], y=[8376], train_mask=[8376], val_mask=[8376], test_mask=[8376], n_id=[8376], e_id=[19617], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8484, 767], edge_index=[2, 20029], y=[8484], train_mask=[8484], val_mask=[8484], test_mask=[8484], n_id=[8484], e_id=[20029], input_id=[1024], batch_size=1024)
# Batch : Data(x=[7486, 767], edge_index=[2, 15857], y=[7486], train_mask=[7486], val_mask=[7486], test_mask=[7486], n_id=[7486], e_id=[15857], input_id=[761], batch_size=761)
# Epoch  20 | Train Loss: 0.064 | Train Acc:  75.11% | Val Loss: 0.80 | Val Acc: 71.02%
# Batch : Data(x=[8420, 767], edge_index=[2, 19838], y=[8420], train_mask=[8420], val_mask=[8420], test_mask=[8420], n_id=[8420], e_id=[19838], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8420, 767], edge_index=[2, 19879], y=[8420], train_mask=[8420], val_mask=[8420], test_mask=[8420], n_id=[8420], e_id=[19879], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8445, 767], edge_index=[2, 19863], y=[8445], train_mask=[8445], val_mask=[8445], test_mask=[8445], n_id=[8445], e_id=[19863], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8396, 767], edge_index=[2, 19723], y=[8396], train_mask=[8396], val_mask=[8396], test_mask=[8396], n_id=[8396], e_id=[19723], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8457, 767], edge_index=[2, 19748], y=[8457], train_mask=[8457], val_mask=[8457], test_mask=[8457], n_id=[8457], e_id=[19748], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8457, 767], edge_index=[2, 19965], y=[8457], train_mask=[8457], val_mask=[8457], test_mask=[8457], n_id=[8457], e_id=[19965], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8505, 767], edge_index=[2, 19875], y=[8505], train_mask=[8505], val_mask=[8505], test_mask=[8505], n_id=[8505], e_id=[19875], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8491, 767], edge_index=[2, 19994], y=[8491], train_mask=[8491], val_mask=[8491], test_mask=[8491], n_id=[8491], e_id=[19994], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8389, 767], edge_index=[2, 19476], y=[8389], train_mask=[8389], val_mask=[8389], test_mask=[8389], n_id=[8389], e_id=[19476], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8452, 767], edge_index=[2, 19847], y=[8452], train_mask=[8452], val_mask=[8452], test_mask=[8452], n_id=[8452], e_id=[19847], input_id=[1024], batch_size=1024)
# Batch : Data(x=[7529, 767], edge_index=[2, 15839], y=[7529], train_mask=[7529], val_mask=[7529], test_mask=[7529], n_id=[7529], e_id=[15839], input_id=[761], batch_size=761)
# Epoch  21 | Train Loss: 0.066 | Train Acc:  75.30% | Val Loss: 0.80 | Val Acc: 71.88%
# Batch : Data(x=[8381, 767], edge_index=[2, 19730], y=[8381], train_mask=[8381], val_mask=[8381], test_mask=[8381], n_id=[8381], e_id=[19730], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8477, 767], edge_index=[2, 19891], y=[8477], train_mask=[8477], val_mask=[8477], test_mask=[8477], n_id=[8477], e_id=[19891], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8417, 767], edge_index=[2, 19775], y=[8417], train_mask=[8417], val_mask=[8417], test_mask=[8417], n_id=[8417], e_id=[19775], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8470, 767], edge_index=[2, 20149], y=[8470], train_mask=[8470], val_mask=[8470], test_mask=[8470], n_id=[8470], e_id=[20149], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8456, 767], edge_index=[2, 19950], y=[8456], train_mask=[8456], val_mask=[8456], test_mask=[8456], n_id=[8456], e_id=[19950], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8451, 767], edge_index=[2, 19714], y=[8451], train_mask=[8451], val_mask=[8451], test_mask=[8451], n_id=[8451], e_id=[19714], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8453, 767], edge_index=[2, 19827], y=[8453], train_mask=[8453], val_mask=[8453], test_mask=[8453], n_id=[8453], e_id=[19827], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8419, 767], edge_index=[2, 20033], y=[8419], train_mask=[8419], val_mask=[8419], test_mask=[8419], n_id=[8419], e_id=[20033], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8383, 767], edge_index=[2, 19574], y=[8383], train_mask=[8383], val_mask=[8383], test_mask=[8383], n_id=[8383], e_id=[19574], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8465, 767], edge_index=[2, 19854], y=[8465], train_mask=[8465], val_mask=[8465], test_mask=[8465], n_id=[8465], e_id=[19854], input_id=[1024], batch_size=1024)
# Batch : Data(x=[7551, 767], edge_index=[2, 15783], y=[7551], train_mask=[7551], val_mask=[7551], test_mask=[7551], n_id=[7551], e_id=[15783], input_id=[761], batch_size=761)
# Epoch  22 | Train Loss: 0.064 | Train Acc:  75.58% | Val Loss: 0.78 | Val Acc: 72.19%
# Batch : Data(x=[8473, 767], edge_index=[2, 19980], y=[8473], train_mask=[8473], val_mask=[8473], test_mask=[8473], n_id=[8473], e_id=[19980], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8456, 767], edge_index=[2, 19758], y=[8456], train_mask=[8456], val_mask=[8456], test_mask=[8456], n_id=[8456], e_id=[19758], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8495, 767], edge_index=[2, 20048], y=[8495], train_mask=[8495], val_mask=[8495], test_mask=[8495], n_id=[8495], e_id=[20048], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8414, 767], edge_index=[2, 19843], y=[8414], train_mask=[8414], val_mask=[8414], test_mask=[8414], n_id=[8414], e_id=[19843], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8453, 767], edge_index=[2, 19956], y=[8453], train_mask=[8453], val_mask=[8453], test_mask=[8453], n_id=[8453], e_id=[19956], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8452, 767], edge_index=[2, 19783], y=[8452], train_mask=[8452], val_mask=[8452], test_mask=[8452], n_id=[8452], e_id=[19783], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8493, 767], edge_index=[2, 19903], y=[8493], train_mask=[8493], val_mask=[8493], test_mask=[8493], n_id=[8493], e_id=[19903], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8384, 767], edge_index=[2, 19940], y=[8384], train_mask=[8384], val_mask=[8384], test_mask=[8384], n_id=[8384], e_id=[19940], input_id=[1024], batch_size=1024)
# ...
# Batch : Data(x=[8399, 767], edge_index=[2, 19864], y=[8399], train_mask=[8399], val_mask=[8399], test_mask=[8399], n_id=[8399], e_id=[19864], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8387, 767], edge_index=[2, 19803], y=[8387], train_mask=[8387], val_mask=[8387], test_mask=[8387], n_id=[8387], e_id=[19803], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8403, 767], edge_index=[2, 19798], y=[8403], train_mask=[8403], val_mask=[8403], test_mask=[8403], n_id=[8403], e_id=[19798], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8439, 767], edge_index=[2, 19867], y=[8439], train_mask=[8439], val_mask=[8439], test_mask=[8439], n_id=[8439], e_id=[19867], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8443, 767], edge_index=[2, 19791], y=[8443], train_mask=[8443], val_mask=[8443], test_mask=[8443], n_id=[8443], e_id=[19791], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8454, 767], edge_index=[2, 19985], y=[8454], train_mask=[8454], val_mask=[8454], test_mask=[8454], n_id=[8454], e_id=[19985], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8430, 767], edge_index=[2, 19647], y=[8430], train_mask=[8430], val_mask=[8430], test_mask=[8430], n_id=[8430], e_id=[19647], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8331, 767], edge_index=[2, 19732], y=[8331], train_mask=[8331], val_mask=[8331], test_mask=[8331], n_id=[8331], e_id=[19732], input_id=[1024], batch_size=1024)
# Batch : Data(x=[7458, 767], edge_index=[2, 15705], y=[7458], train_mask=[7458], val_mask=[7458], test_mask=[7458], n_id=[7458], e_id=[15705], input_id=[761], batch_size=761)
# Epoch 193 | Train Loss: 0.050 | Train Acc:  80.98% | Val Loss: 1.05 | Val Acc: 72.53%
# Batch : Data(x=[8468, 767], edge_index=[2, 19767], y=[8468], train_mask=[8468], val_mask=[8468], test_mask=[8468], n_id=[8468], e_id=[19767], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8366, 767], edge_index=[2, 19602], y=[8366], train_mask=[8366], val_mask=[8366], test_mask=[8366], n_id=[8366], e_id=[19602], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8494, 767], edge_index=[2, 19879], y=[8494], train_mask=[8494], val_mask=[8494], test_mask=[8494], n_id=[8494], e_id=[19879], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8494, 767], edge_index=[2, 20001], y=[8494], train_mask=[8494], val_mask=[8494], test_mask=[8494], n_id=[8494], e_id=[20001], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8415, 767], edge_index=[2, 19926], y=[8415], train_mask=[8415], val_mask=[8415], test_mask=[8415], n_id=[8415], e_id=[19926], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8398, 767], edge_index=[2, 19744], y=[8398], train_mask=[8398], val_mask=[8398], test_mask=[8398], n_id=[8398], e_id=[19744], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8548, 767], edge_index=[2, 19993], y=[8548], train_mask=[8548], val_mask=[8548], test_mask=[8548], n_id=[8548], e_id=[19993], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8396, 767], edge_index=[2, 19751], y=[8396], train_mask=[8396], val_mask=[8396], test_mask=[8396], n_id=[8396], e_id=[19751], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8404, 767], edge_index=[2, 19577], y=[8404], train_mask=[8404], val_mask=[8404], test_mask=[8404], n_id=[8404], e_id=[19577], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8459, 767], edge_index=[2, 19802], y=[8459], train_mask=[8459], val_mask=[8459], test_mask=[8459], n_id=[8459], e_id=[19802], input_id=[1024], batch_size=1024)
# Batch : Data(x=[7510, 767], edge_index=[2, 15747], y=[7510], train_mask=[7510], val_mask=[7510], test_mask=[7510], n_id=[7510], e_id=[15747], input_id=[761], batch_size=761)
# Epoch 194 | Train Loss: 0.047 | Train Acc:  81.02% | Val Loss: 1.06 | Val Acc: 72.38%
# Batch : Data(x=[8449, 767], edge_index=[2, 19847], y=[8449], train_mask=[8449], val_mask=[8449], test_mask=[8449], n_id=[8449], e_id=[19847], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8449, 767], edge_index=[2, 20050], y=[8449], train_mask=[8449], val_mask=[8449], test_mask=[8449], n_id=[8449], e_id=[20050], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8531, 767], edge_index=[2, 20027], y=[8531], train_mask=[8531], val_mask=[8531], test_mask=[8531], n_id=[8531], e_id=[20027], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8448, 767], edge_index=[2, 19792], y=[8448], train_mask=[8448], val_mask=[8448], test_mask=[8448], n_id=[8448], e_id=[19792], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8502, 767], edge_index=[2, 19989], y=[8502], train_mask=[8502], val_mask=[8502], test_mask=[8502], n_id=[8502], e_id=[19989], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8431, 767], edge_index=[2, 19904], y=[8431], train_mask=[8431], val_mask=[8431], test_mask=[8431], n_id=[8431], e_id=[19904], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8501, 767], edge_index=[2, 19841], y=[8501], train_mask=[8501], val_mask=[8501], test_mask=[8501], n_id=[8501], e_id=[19841], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8374, 767], edge_index=[2, 19895], y=[8374], train_mask=[8374], val_mask=[8374], test_mask=[8374], n_id=[8374], e_id=[19895], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8409, 767], edge_index=[2, 19676], y=[8409], train_mask=[8409], val_mask=[8409], test_mask=[8409], n_id=[8409], e_id=[19676], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8344, 767], edge_index=[2, 19749], y=[8344], train_mask=[8344], val_mask=[8344], test_mask=[8344], n_id=[8344], e_id=[19749], input_id=[1024], batch_size=1024)
# Batch : Data(x=[7505, 767], edge_index=[2, 15772], y=[7505], train_mask=[7505], val_mask=[7505], test_mask=[7505], n_id=[7505], e_id=[15772], input_id=[761], batch_size=761)
# Epoch 195 | Train Loss: 0.047 | Train Acc:  80.75% | Val Loss: 1.07 | Val Acc: 71.26%
# Batch : Data(x=[8376, 767], edge_index=[2, 19600], y=[8376], train_mask=[8376], val_mask=[8376], test_mask=[8376], n_id=[8376], e_id=[19600], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8443, 767], edge_index=[2, 19839], y=[8443], train_mask=[8443], val_mask=[8443], test_mask=[8443], n_id=[8443], e_id=[19839], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8534, 767], edge_index=[2, 19976], y=[8534], train_mask=[8534], val_mask=[8534], test_mask=[8534], n_id=[8534], e_id=[19976], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8465, 767], edge_index=[2, 19763], y=[8465], train_mask=[8465], val_mask=[8465], test_mask=[8465], n_id=[8465], e_id=[19763], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8495, 767], edge_index=[2, 19858], y=[8495], train_mask=[8495], val_mask=[8495], test_mask=[8495], n_id=[8495], e_id=[19858], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8452, 767], edge_index=[2, 19613], y=[8452], train_mask=[8452], val_mask=[8452], test_mask=[8452], n_id=[8452], e_id=[19613], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8534, 767], edge_index=[2, 20139], y=[8534], train_mask=[8534], val_mask=[8534], test_mask=[8534], n_id=[8534], e_id=[20139], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8447, 767], edge_index=[2, 19884], y=[8447], train_mask=[8447], val_mask=[8447], test_mask=[8447], n_id=[8447], e_id=[19884], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8423, 767], edge_index=[2, 19614], y=[8423], train_mask=[8423], val_mask=[8423], test_mask=[8423], n_id=[8423], e_id=[19614], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8385, 767], edge_index=[2, 19800], y=[8385], train_mask=[8385], val_mask=[8385], test_mask=[8385], n_id=[8385], e_id=[19800], input_id=[1024], batch_size=1024)
# Batch : Data(x=[7539, 767], edge_index=[2, 15871], y=[7539], train_mask=[7539], val_mask=[7539], test_mask=[7539], n_id=[7539], e_id=[15871], input_id=[761], batch_size=761)
# Epoch 196 | Train Loss: 0.049 | Train Acc:  81.12% | Val Loss: 1.02 | Val Acc: 72.12%
# Batch : Data(x=[8447, 767], edge_index=[2, 19780], y=[8447], train_mask=[8447], val_mask=[8447], test_mask=[8447], n_id=[8447], e_id=[19780], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8532, 767], edge_index=[2, 19986], y=[8532], train_mask=[8532], val_mask=[8532], test_mask=[8532], n_id=[8532], e_id=[19986], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8466, 767], edge_index=[2, 19988], y=[8466], train_mask=[8466], val_mask=[8466], test_mask=[8466], n_id=[8466], e_id=[19988], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8404, 767], edge_index=[2, 19880], y=[8404], train_mask=[8404], val_mask=[8404], test_mask=[8404], n_id=[8404], e_id=[19880], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8410, 767], edge_index=[2, 19869], y=[8410], train_mask=[8410], val_mask=[8410], test_mask=[8410], n_id=[8410], e_id=[19869], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8457, 767], edge_index=[2, 19776], y=[8457], train_mask=[8457], val_mask=[8457], test_mask=[8457], n_id=[8457], e_id=[19776], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8464, 767], edge_index=[2, 19786], y=[8464], train_mask=[8464], val_mask=[8464], test_mask=[8464], n_id=[8464], e_id=[19786], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8391, 767], edge_index=[2, 19860], y=[8391], train_mask=[8391], val_mask=[8391], test_mask=[8391], n_id=[8391], e_id=[19860], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8400, 767], edge_index=[2, 19764], y=[8400], train_mask=[8400], val_mask=[8400], test_mask=[8400], n_id=[8400], e_id=[19764], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8420, 767], edge_index=[2, 19854], y=[8420], train_mask=[8420], val_mask=[8420], test_mask=[8420], n_id=[8420], e_id=[19854], input_id=[1024], batch_size=1024)
# Batch : Data(x=[7609, 767], edge_index=[2, 15804], y=[7609], train_mask=[7609], val_mask=[7609], test_mask=[7609], n_id=[7609], e_id=[15804], input_id=[761], batch_size=761)
# Epoch 197 | Train Loss: 0.046 | Train Acc:  81.04% | Val Loss: 1.04 | Val Acc: 72.82%
# Batch : Data(x=[8433, 767], edge_index=[2, 19708], y=[8433], train_mask=[8433], val_mask=[8433], test_mask=[8433], n_id=[8433], e_id=[19708], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8419, 767], edge_index=[2, 20008], y=[8419], train_mask=[8419], val_mask=[8419], test_mask=[8419], n_id=[8419], e_id=[20008], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8488, 767], edge_index=[2, 20047], y=[8488], train_mask=[8488], val_mask=[8488], test_mask=[8488], n_id=[8488], e_id=[20047], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8437, 767], edge_index=[2, 19796], y=[8437], train_mask=[8437], val_mask=[8437], test_mask=[8437], n_id=[8437], e_id=[19796], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8459, 767], edge_index=[2, 20020], y=[8459], train_mask=[8459], val_mask=[8459], test_mask=[8459], n_id=[8459], e_id=[20020], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8456, 767], edge_index=[2, 19807], y=[8456], train_mask=[8456], val_mask=[8456], test_mask=[8456], n_id=[8456], e_id=[19807], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8446, 767], edge_index=[2, 19862], y=[8446], train_mask=[8446], val_mask=[8446], test_mask=[8446], n_id=[8446], e_id=[19862], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8486, 767], edge_index=[2, 19999], y=[8486], train_mask=[8486], val_mask=[8486], test_mask=[8486], n_id=[8486], e_id=[19999], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8380, 767], edge_index=[2, 19693], y=[8380], train_mask=[8380], val_mask=[8380], test_mask=[8380], n_id=[8380], e_id=[19693], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8386, 767], edge_index=[2, 19772], y=[8386], train_mask=[8386], val_mask=[8386], test_mask=[8386], n_id=[8386], e_id=[19772], input_id=[1024], batch_size=1024)
# Batch : Data(x=[7485, 767], edge_index=[2, 15737], y=[7485], train_mask=[7485], val_mask=[7485], test_mask=[7485], n_id=[7485], e_id=[15737], input_id=[761], batch_size=761)
# Epoch 198 | Train Loss: 0.047 | Train Acc:  81.03% | Val Loss: 1.07 | Val Acc: 72.03%
# Batch : Data(x=[8379, 767], edge_index=[2, 19734], y=[8379], train_mask=[8379], val_mask=[8379], test_mask=[8379], n_id=[8379], e_id=[19734], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8471, 767], edge_index=[2, 19859], y=[8471], train_mask=[8471], val_mask=[8471], test_mask=[8471], n_id=[8471], e_id=[19859], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8469, 767], edge_index=[2, 19973], y=[8469], train_mask=[8469], val_mask=[8469], test_mask=[8469], n_id=[8469], e_id=[19973], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8458, 767], edge_index=[2, 19928], y=[8458], train_mask=[8458], val_mask=[8458], test_mask=[8458], n_id=[8458], e_id=[19928], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8420, 767], edge_index=[2, 19972], y=[8420], train_mask=[8420], val_mask=[8420], test_mask=[8420], n_id=[8420], e_id=[19972], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8438, 767], edge_index=[2, 19937], y=[8438], train_mask=[8438], val_mask=[8438], test_mask=[8438], n_id=[8438], e_id=[19937], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8428, 767], edge_index=[2, 19742], y=[8428], train_mask=[8428], val_mask=[8428], test_mask=[8428], n_id=[8428], e_id=[19742], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8366, 767], edge_index=[2, 19957], y=[8366], train_mask=[8366], val_mask=[8366], test_mask=[8366], n_id=[8366], e_id=[19957], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8397, 767], edge_index=[2, 19674], y=[8397], train_mask=[8397], val_mask=[8397], test_mask=[8397], n_id=[8397], e_id=[19674], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8351, 767], edge_index=[2, 19720], y=[8351], train_mask=[8351], val_mask=[8351], test_mask=[8351], n_id=[8351], e_id=[19720], input_id=[1024], batch_size=1024)
# Batch : Data(x=[7644, 767], edge_index=[2, 15991], y=[7644], train_mask=[7644], val_mask=[7644], test_mask=[7644], n_id=[7644], e_id=[15991], input_id=[761], batch_size=761)
# Epoch 199 | Train Loss: 0.047 | Train Acc:  80.77% | Val Loss: 1.06 | Val Acc: 72.40%
# Batch : Data(x=[8409, 767], edge_index=[2, 19687], y=[8409], train_mask=[8409], val_mask=[8409], test_mask=[8409], n_id=[8409], e_id=[19687], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8474, 767], edge_index=[2, 19861], y=[8474], train_mask=[8474], val_mask=[8474], test_mask=[8474], n_id=[8474], e_id=[19861], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8397, 767], edge_index=[2, 19902], y=[8397], train_mask=[8397], val_mask=[8397], test_mask=[8397], n_id=[8397], e_id=[19902], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8456, 767], edge_index=[2, 19753], y=[8456], train_mask=[8456], val_mask=[8456], test_mask=[8456], n_id=[8456], e_id=[19753], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8486, 767], edge_index=[2, 20117], y=[8486], train_mask=[8486], val_mask=[8486], test_mask=[8486], n_id=[8486], e_id=[20117], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8411, 767], edge_index=[2, 19942], y=[8411], train_mask=[8411], val_mask=[8411], test_mask=[8411], n_id=[8411], e_id=[19942], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8377, 767], edge_index=[2, 19701], y=[8377], train_mask=[8377], val_mask=[8377], test_mask=[8377], n_id=[8377], e_id=[19701], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8421, 767], edge_index=[2, 19814], y=[8421], train_mask=[8421], val_mask=[8421], test_mask=[8421], n_id=[8421], e_id=[19814], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8446, 767], edge_index=[2, 19695], y=[8446], train_mask=[8446], val_mask=[8446], test_mask=[8446], n_id=[8446], e_id=[19695], input_id=[1024], batch_size=1024)
# Batch : Data(x=[8461, 767], edge_index=[2, 19955], y=[8461], train_mask=[8461], val_mask=[8461], test_mask=[8461], n_id=[8461], e_id=[19955], input_id=[1024], batch_size=1024)
# Batch : Data(x=[7462, 767], edge_index=[2, 15611], y=[7462], train_mask=[7462], val_mask=[7462], test_mask=[7462], n_id=[7462], e_id=[15611], input_id=[761], batch_size=761)
# Epoch 200 | Train Loss: 0.046 | Train Acc:  81.31% | Val Loss: 1.05 | Val Acc: 71.64%
# GraphSAGE test accuracy: 87.06%
